# %%
import pickle
import gzip

# load the replay index
with gzip.open('/Users/Peace/Desktop/replays/INDEX.pkl', 'rb') as infile:
    master_index = pickle.load(infile)

# %%
rnames = list(master_index.keys())

# %%
master_index[rnames[0]]
# Out:
# {'ENGINE_VERSION': '0.6.2.prelaunch.51.g40db6',
#  'GAME_CONSTANTS': {'CAPTURE_ENABLED': False,
#   'CAPTURE_RADIUS': 3,
#   'DEFAULT_MAP_HEIGHT': 40,
#   'DEFAULT_MAP_WIDTH': 40,
#   'DROPOFF_COST': 4000,
#   'DROPOFF_PENALTY_RATIO': 4,
#   'EXTRACT_RATIO': 4,
#   'FACTOR_EXP_1': 2.0,
#   'FACTOR_EXP_2': 2.0,
#   'INITIAL_ENERGY': 5000,
#   'INSPIRATION_ENABLED': True,
#   'INSPIRATION_RADIUS': 4,
#   'INSPIRATION_SHIP_COUNT': 2,
#   'INSPIRED_BONUS_MULTIPLIER': 2.0,
#   'INSPIRED_EXTRACT_RATIO': 4,
#   'INSPIRED_MOVE_COST_RATIO': 10,
#   'MAX_CELL_PRODUCTION': 1000,
#   'MAX_ENERGY': 1000,
#   'MAX_PLAYERS': 16,
#   'MAX_TURNS': 425,
#   'MAX_TURN_THRESHOLD': 64,
#   'MIN_CELL_PRODUCTION': 900,
#   'MIN_TURNS': 400,
#   'MIN_TURN_THRESHOLD': 32,
#   'MOVE_COST_RATIO': 10,
#   'NEW_ENTITY_ENERGY_COST': 1000,
#   'PERSISTENCE': 0.7,
#   'SHIPS_ABOVE_FOR_CAPTURE': 3,
#   'STRICT_ERRORS': False},
#  'REPLAY_FILE_VERSION': 3,
#  'game_statistics': {'number_turns': 426,
#   'player_statistics': [{'all_collisions': 23,
#     'average_entity_distance': 9,
#     'final_production': 97457,
#     'halite_per_dropoff': [[{'x': 11, 'y': 11}, 116457]],
#     'interaction_opportunities': 931,
#     'last_turn_alive': 426,
#     'max_entity_distance': 30,
#     'mining_efficiency': 1.2103326785769963,
#     'number_dropoffs': 0,
#     'player_id': 0,
#     'random_id': 263681306,
#     'rank': 1,
#     'self_collisions': 23,
#     'ships_captured': 0,
#     'ships_given': 0,
#     'total_bonus': 35785,
#     'total_mined': 96219,
#     'total_mined_from_captured': 0,
#     'total_production': 116457},
#    {'all_collisions': 49,
#     'average_entity_distance': 10,
#     'final_production': 91929,
#     'halite_per_dropoff': [[{'x': 39, 'y': 19}, 15668],
#      [{'x': 19, 'y': 0}, 18680],
#      [{'x': 28, 'y': 11}, 74096],
#      [{'x': 37, 'y': 0}, 42485]],
#     'interaction_opportunities': 1308,
#     'last_turn_alive': 426,
#     'max_entity_distance': 29,
#     'mining_efficiency': 1.4796525592384537,
#     'number_dropoffs': 3,
#     'player_id': 1,
#     'random_id': 3456025926,
#     'rank': 2,
#     'self_collisions': 22,
#     'ships_captured': 0,
#     'ships_given': 0,
#     'total_bonus': 73786,
#     'total_mined': 102003,
#     'total_mined_from_captured': 0,
#     'total_production': 150929},
#    {'all_collisions': 40,
#     'average_entity_distance': 10,
#     'final_production': 81174,
#     'halite_per_dropoff': [[{'x': 4, 'y': 38}, 44341],
#      [{'x': 11, 'y': 28}, 76833]],
#     'interaction_opportunities': 940,
#     'last_turn_alive': 426,
#     'max_entity_distance': 35,
#     'mining_efficiency': 1.2446612911509425,
#     'number_dropoffs': 1,
#     'player_id': 2,
#     'random_id': 4070726604,
#     'rank': 3,
#     'self_collisions': 0,
#     'ships_captured': 0,
#     'ships_given': 0,
#     'total_bonus': 45688,
#     'total_mined': 97355,
#     'total_mined_from_captured': 0,
#     'total_production': 121174},
#    {'all_collisions': 59,
#     'average_entity_distance': 10,
#     'final_production': 78365,
#     'halite_per_dropoff': [[{'x': 38, 'y': 34}, 22210],
#      [{'x': 28, 'y': 28}, 78311],
#      [{'x': 23, 'y': 39}, 41844]],
#     'interaction_opportunities': 1241,
#     'last_turn_alive': 426,
#     'max_entity_distance': 30,
#     'mining_efficiency': 1.2236767461449862,
#     'number_dropoffs': 2,
#     'player_id': 3,
#     'random_id': 1377968360,
#     'rank': 4,
#     'self_collisions': 0,
#     'ships_captured': 0,
#     'ships_given': 0,
#     'total_bonus': 63775,
#     'total_mined': 116342,
#     'total_mined_from_captured': 0,
#     'total_production': 142365}]},
#  'map_generator_seed': 1539480252,
#  'number_of_players': 4,
#  'players': [{'energy': 5000,
#    'entities': [],
#    'factory_location': {'x': 11, 'y': 11},
#    'name': 'shummie v58',
#    'player_id': 0},
#   {'energy': 5000,
#    'entities': [],
#    'factory_location': {'x': 28, 'y': 11},
#    'name': 'Lunariz v30',
#    'player_id': 1},
#   {'energy': 5000,
#    'entities': [],
#    'factory_location': {'x': 11, 'y': 28},
#    'name': 'daeglin v13',
#    'player_id': 2},
#   {'energy': 5000,
#    'entities': [],
#    'factory_location': {'x': 28, 'y': 28},
#    'name': 'tsgreczner v20',
#    'player_id': 3}]}
